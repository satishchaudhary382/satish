# %% [markdown]
# <a href="https://colab.research.google.com/github/satishchaudhary382/satish/blob/master/Gapminder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from celluloid import Camera
url = "https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv"
dataset = pd.read_csv(url)

years = ["1952", "1962", "1967", "1972", "1977", "1982", "1987", "1992", "1997", "2002",
         "2007"]

# %%
df_1 = pd.pivot_table(dataset, index = ["year",'country'])
no_of_years = []
for y in years:
  c = df_1.query(f"year ==[{y}]")
  
  exec(f"df_{y} = c")
  exec(f"df_{y} = df_{y}.reset_index()")
  print(exec(f"df_{y}"))
  
#df_1952 = df_1.query("year ==['1952']")
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
ye = [1952, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,2007]

# %%
for i in [df_1952, df_1962, df_1967, df_1972, df_1977, df_1982, df_1987, df_1992, df_1997, df_2007]:
  f = i.reset_index()
  print(f)
# Out:
#      index  year             country    gdpPercap  lifeExp         pop
# 0        0  1952         Afghanistan   779.445314   28.801   8425333.0
# 1        1  1952             Albania  1601.056136   55.230   1282697.0
# 2        2  1952             Algeria  2449.008185   43.077   9279525.0
# 3        3  1952              Angola  3520.610273   30.015   4232095.0
# 4        4  1952           Argentina  5911.315053   62.485  17876956.0
# ..     ...   ...                 ...          ...      ...         ...
# 137    137  1952             Vietnam   605.066492   40.412  26246839.0
# 138    138  1952  West Bank and Gaza  1515.592329   43.160   1030585.0
# 139    139  1952         Yemen, Rep.   781.717576   32.548   4963829.0
# 140    140  1952              Zambia  1147.388831   42.038   2672000.0
# 141    141  1952            Zimbabwe   406.884115   48.451   3080907.0
#
# [142 rows x 6 columns]
#      index  year             country    gdpPercap  lifeExp         pop
# ...

# %%
fig = plt.figure()
camera = Camera(fig)
for year in [df_1952, df_1962, df_1967, df_1972, df_1977, df_1982, df_1987, df_1992, df_1997, df_2007]:
  i = year.values
  #print(i[0][0])
  for t in ye:

    if i[0][0] == int(t):
      for j in range(0,len(i)):
        plt.scatter(i[j][3],i[j][2], s = i[j][4]*0.000001, c = "b")
      camera.snap()
        #print(i[j][2])
    #   plt.scatter(i[2],i[3], s=i[4]*0.000001)

# %%
animation = camera.animate()
animation.save("abc.mp4")

# %%
from IPython.display import HTML
HTML(animation.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
